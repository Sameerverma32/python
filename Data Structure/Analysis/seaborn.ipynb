# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Count plot
sns.countplot(df, x='survived', hue='sex')
plt.title('Survived vs Not Survived by gender')
plt.show()

# %%
sns.countplot(df, x="class",palette='viridis')
plt.title('number of passenger by class')
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10212\2099246214.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df, x="class",palette='viridis')

# %%
sns.countplot(df, y="class",palette='viridis')
plt.title('number of passenger by class')
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10212\3609765957.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df, y="class",palette='viridis')

# %%
sns.barplot(df,x='class', y='survived', palette='coolwarm')
plt.title('survival rate by class')
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10212\1906899378.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(df,x='class', y='survived', palette='coolwarm')

# %%
sns.histplot(df, x='age',bins=30, palette='coolwarm', kde=True)
plt.title('Survival rate by age')
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10212\2684720698.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df, x='age',bins=30, palette='coolwarm', kde=True)

# %%
sns.violinplot(df, x='class', y='age', hue='sex', split=True, palette='Set2')
plt.title('Age distibution by class')
plt.show()

# %%
sns.violinplot(df, x='class', y='age', hue='sex', split=True, palette='tab10')
plt.title('Age distibution by class')
plt.show()

# %%
sns.violinplot(df, x='class', y='age', hue='sex', split=True, palette='terrain')
plt.title('Age distibution by class')
plt.show()

# %%
sns.scatterplot(df, x='age', y='fare', hue='survived',palette='winter')
plt.title('Fare vs Age by survived')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.scatterplot(df, x='age', y='fare', hue='survived',palette='terrain')
plt.title('Fare vs Age by survived')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(df[['age','fare','survived','pclass']],hue='survived',palette='terrain')
plt.show()

# %%
sns.pairplot(df[['age','fare','survived','pclass']],hue='survived',palette='spring')
plt.show()

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
import numpy as np

week1 = [20,25,22,45,30]
week2 = [17,23,21,28,40]
week3 = [22,23,25,35,33]
week4 = [21,26,22,40,36]

data = np.array([week1,week2,week3,week4])

sns.heatmap(data, cmap='coolwarm')
plt.title('matrix')
plt.show()

# %%
sns.scatterplot(df, x="sepal_length",y="petal_length", hue='species', palette="spring")
plt.title('Comperesion between sepal.length ')
plt.show()

# %%
sns.histplot(df, x='sepal_length',kde=True,palette='Accent')
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10212\1689740984.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df, x='sepal_length',kde=True,palette='Accent')
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.boxplot(df,x='sepal_width',y='species',palette='CMRmap')
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10212\2338428381.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(df,x='sepal_width',y='species',palette='CMRmap')
# <Axes: xlabel='sepal_width', ylabel='species'>

# %%
sns.violinplot(df, x="petal_length",y='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='species'>

# %%
sns.countplot(df, x='species',palette='spring',alpha=0.5)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10212\1587155951.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df, x='species',palette='spring',alpha=0.5)
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.relplot(df, x='sepal_length', y='sepal_width',palette='spring',)
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_10212\3723484375.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.relplot(df, x='sepal_length', y='sepal_width',palette='spring',)

# %%
sns.rugplot(df, x="sepal_width", y="petal_length",hue='species')
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_length'>

# %%
sns.swarmplot(df, x='sepal_length', y='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='species'>

# %%
sns.pairplot(df[['petal_length','petal_width','sepal_length','sepal_width']],hue='sepal_length', palette='spring')
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('car_crashes')
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.isnull().sum()
# Out:
# total             0
# speeding          0
# alcohol           0
# not_distracted    0
# no_previous       0
# ins_premium       0
# ins_losses        0
# abbrev            0
# dtype: int64

# %%
sns.pairplot(df[['speeding','alcohol','not_distracted','no_previous']],hue='no_previous', palette='Greens')
plt.show()

# %%
sns.swarmplot(df, y='abbrev', x='ins_premium')
# Out:
# <Axes: xlabel='ins_premium', ylabel='abbrev'>

# %%
sns.regplot(df, x='alcohol', y='speeding')
# Out:
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %%
sns.catplot(df, x='alcohol', y='ins_losses')

# %%
sns.scatterplot(df, y="alcohol",x="speeding", hue='ins_losses', palette="spring")
plt.title('Comperission between speeding and alcohol')
plt.show()

# %%
sns.jointplot(df, x='alcohol', y='speeding')

# %%
sns.kdeplot(df, x='speeding', y='alcohol')
plt.title("kdeplot")
# Out:
# Text(0.5, 1.0, 'kdeplot')

# %%
sns.stripplot(df, x='alcohol', y='ins_losses')
# Out:
# <Axes: xlabel='alcohol', ylabel='ins_losses'>

# %%
sns.catplot(df, x='speeding', y='alcohol')
